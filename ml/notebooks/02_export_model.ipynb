# %% [markdown]
# # Export Model and Artifacts
# This notebook exports the trained model, encoders, and metadata for deployment.

# %%
import joblib
import json
from pathlib import Path
from datetime import datetime

# %%
# %run ./01_train_model.ipynb
# Out:
# bone_density               float64
# vision_sharpness           float64
# hearing_ability            float64
# physical_activity_level      int64
# smoking_status               int64
# alcohol_consumption        float64
# diet                         int64
# mental_health_status         int64
# sleep_patterns               int64
# stress_levels              float64
# income_level                 int64
# age                          int64
# dtype: object
# wb_fruits_veggies    int64
# wb_daily_stress      int64
# wb_places_visited    int64
# wb_core_cirle        int64
# wb_daily_steps       int64
# wb_sleep_hours       int64
# age                    str
# dtype: object
# MAE: 4.789032459259033
# R²: 0.9088882207870483
# range: 18 - 89
# mean: 53.48566666666667
# median: 53.0
# age_group
# Young     3.490937
# Middle    5.397493
# Senior    5.588566
# Elder     4.517482
# Name: abs_error, dtype: float64

# %%
# create folder models if doesn't exist
models_dir = Path('../models')
models_dir.mkdir(exist_ok=True)
print(f"Models directory: {models_dir.resolve()}")
# Out:
# ..\models
# Models directory: C:\Users\trejos10\OneDrive - Corning Incorporated\code\age-ml-model\ml\models

# %%
# creates path for model and saves into that path
model_path = models_dir / 'age_model_v1.joblib'
joblib.dump(model, model_path, compress=3)
print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ..\models\age_model_v1.joblib

# %%
# saves the dictionary of the encoding labels to be decoded later
encoders_path = models_dir / 'label_encoders_v1.joblib'
joblib.dump(label_encoders, encoders_path)
print(f"Encoders saved to: {encoders_path}")
print(f"Encoded columns: {list(label_encoders.keys())}")
# Out:
# Encoders saved to: ..\models\label_encoders_v1.joblib
# Encoded columns: ['smoking_status', 'diet', 'sleep_patterns']

# %%
# saves metadata from the model
metadata = {
    'model_version': 'v1',
    'training_date': datetime.now().strftime('%Y-%m-%d'),
    'feature_names': X.columns.tolist(),
    'ordinal_maps': ordinal_map,
    'nominal_cols': nominal_cols,
    'target_column': 'age',
    'training_metrics': {
        'mae': mae,
        'r2': r2
    },
    'model_params': model.get_params()
}

metadata_path = models_dir / 'model_metadata_v1.json'
with open(metadata_path, 'w') as f:
    json.dump(metadata, f, indent=2)
    
print(f"Metadata saved to: {metadata_path}")
# Out:
# Metadata saved to: ..\models\model_metadata_v1.json

# %%
# load artifacts
loaded_model = joblib.load(model_path)
loaded_encoders = joblib.load(encoders_path)

# test prediction on X_test
test_idx = 0
test_features = X_test.iloc[[test_idx]]
test_prediction = loaded_model.predict(test_features)
actual_age = y_test.iloc[test_idx]

print(f"Test Sample {test_idx}:")
print(f"  Predicted age: {test_prediction[0]:.2f}")
print(f"  Actual age: {actual_age}")
print(f"  Error: {abs(test_prediction[0] - actual_age):.2f} years")
print("\nExport completed successfully!")
# Out:
# Test Sample 0:
#   Predicted age: 72.55
#   Actual age: 67
#   Error: 5.55 years
#
# Export completed successfully!
